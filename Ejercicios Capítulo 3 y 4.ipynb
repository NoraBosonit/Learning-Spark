# %% [markdown]
# # Ejercicios Python y Scala

# %% [markdown]
# ## Capítulo 3

# %% [markdown]
# ### Ejercicio 2
# Leer el CSV del ejemplo del cap2 y obtener la estructura del schema dado por
# defecto.

# %%
mnm_p = spark.read.csv("/FileStore/tables/mnm_dataset.csv", header=True)

# %%
mnm_p.show
# Out:
# Out[11]: <bound method DataFrame.show of DataFrame[State: string, Color: string, Count: string]>

# %%
# %scala 
val mnm_s = spark.read.option("header",true).csv("/FileStore/tables/mnm_dataset.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mnm_s: org.apache.spark.sql.DataFrame = [State: string, Color: string ... 1 more field]
# </div>

# %%
# %scala 
mnm_s.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+-----+
# State| Color|Count|
# +-----+------+-----+
#    TX|   Red|   20|
#    NV|  Blue|   66|
#    CO|  Blue|   79|
#    OR|  Blue|   71|
#    WA|Yellow|   93|
# +-----+------+-----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# #### Python

# %%
mnm_p.schema
# Out:
# Out[12]: StructType(List(StructField(State,StringType,true),StructField(Color,StringType,true),StructField(Count,StringType,true)))

# %% [markdown]
# #### Scala

# %%
# %scala

mnm_s.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- State: string (nullable = true)
# -- Color: string (nullable = true)
# -- Count: string (nullable = true)
#
# </div>

# %% [markdown]
# ### Ejercicio 3
# Cuando se define un schema al definir un campo por ejemplo StructField('Delay',
# FloatType(), True) ¿qué significa el último parámetro Boolean?

# %% [markdown]
# El StructField se utiliza para especificar los nombres de columnas que se quieren poner en es esquema. Luego, el boolean indica si puede hacer nulos en la columna; True indicaría que sí mientras que False lo contrario. Esto indica la siguiente página ```https://spark.apache.org/docs/3.1.1/api/python/reference/api/pyspark.sql.types.StructField.html```

# %% [markdown]
# ### Ejercicio 4
# Dataset vs DataFrame (Scala). ¿En qué se diferencian a nivel de código?

# %% [markdown]
# ### Ejercicio 5
# Utilizando el mismo ejemplo utilizado en el capítulo para guardar en parquet y
# guardar los datos en los formatos:
#
# i. JSON
#
# ii. CSV (dándole otro nombre para evitar sobrescribir el fichero origen)
#
# iii. AVRO

# %% [markdown]
# #### Python

# %%
#JSON
(mnm_p.write.format("json")
 .mode("overwrite")
 .save("/tmp/data/json/mnm_json"))
#CSV
mnm_p.write.format("csv").mode("overwrite").save("/tmp/data/csv/mnm_csv")
#AVRO
(mnm_p.write
 .format("avro")
 .mode("overwrite")
 .save("/tmp/data/avro/mnm_avro"))

# %% [markdown]
# #### Scala

# %%
# %scala
//JSON
mnm_s.write.format("json")
 .mode("overwrite")
 .save("/tmp/data/json/mnm_json_scala")
//CSV
mnm_s.write.format("csv").mode("overwrite").save("/tmp/data/csv/mnm_csv_scala")
//AVRO
mnm_s.write
 .format("avro")
 .mode("overwrite")
 .save("/tmp/data/avro/mnm_avro_scala")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Ejercicio 6
# Revisar al guardar los ficheros (p.e. json, csv, etc) el número de ficheros
# creados, revisar su contenido para comprender (constatar) como se guardan.
#
# i. ¿A qué se debe que hayan más de un fichero?
#
# ii. ¿Cómo obtener el número de particiones de un DataFrame?
#
# iii. ¿Qué formas existen para modificar el número de particiones de un
# DataFrame?
#
# iv. Llevar a cabo el ejemplo modificando el número de particiones a 1 y
# revisar de nuevo el/los ficheros guardados.

# %% [markdown]
# i.
# Esto es debido a que se guarda el fichero con los datos y varios ficheros que contienen metadatos

# %%
#EN CSV
#El fichero
mnm_csv = spark.read.csv("dbfs:/tmp/data/csv/mnm_csv/part-00000-tid-2537299325662574562-f964d42a-a5b5-4cf7-bdfb-12f238154445-21-1-c000.csv", header=True)

# %%
mnm_csv.show(5)
# Out:
# +---+------+---+
# | TX|   Red| 20|
# +---+------+---+
# | NV|  Blue| 66|
# | CO|  Blue| 79|
# | OR|  Blue| 71|
# | WA|Yellow| 93|
# | WY|  Blue| 16|
# +---+------+---+
# only showing top 5 rows

# %%
# %fs
ls '/tmp/data/csv/mnm_csv/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/tmp/data/csv/mnm_csv/_committed_1028874557326275524</td><td>_committed_1028874557326275524</td><td>212</td><td>1651147943000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv/_committed_2537299325662574562</td><td>_committed_2537299325662574562</td><td>200</td><td>1651234079000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv/_committed_4136834951473676589</td><td>_committed_4136834951473676589</td><td>113</td><td>1651147914000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv/_committed_vacuum2926965980024001460</td><td>_committed_vacuum2926965980024001460</td><td>96</td><td>1651234082000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv/_started_2537299325662574562</td><td>_started_2537299325662574562</td><td>0</td><td>1651234078000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv/part-00000-tid-2537299325662574562-f964d42a-a5b5-4cf7-bdfb-12f238154445-21-1-c000.csv</td><td>part-00000-tid-2537299325662574562-f964d42a-a5b5-4cf7-bdfb-12f238154445-21-1-c000.csv</td><td>1184854</td><td>1651234079000</td></tr></tbody></table></div>

# %% [markdown]
# En la tabla anterior, los 5 primeros ficheros son metadatos los cuales referencian al csv.

# %% [markdown]
# ii. Obtener el número de particiones de un DataFrame

# %% [markdown]
# Se obtiene con el siguiente código: ````ds.rdd.getNumPartitions```` siendo ds el Dataset o DataFrame

# %%
# %scala
mnm_s.rdd.getNumPartitions
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res17: Int = 1
# </div>

# %% [markdown]
# Hay solo una partición por lo que muestra solo 1.

# %% [markdown]
# iii. ¿Qué formas existen para modificar el número de particiones de un DataFrame?

# %% [markdown]
# Si quisiésemos más, habría que especificarlo al leer el fichero. De la siguiente forma: ```val mnm_s_par = spark.read.option("header",true).csv("/FileStore/tables/mnm_dataset.csv").repartition(16)```

# %%
# %scala
val mnm_s_par = spark.read.option("header",true).csv("/FileStore/tables/mnm_dataset.csv").repartition(16)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mnm_s_par: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [State: string, Color: string ... 1 more field]
# </div>

# %%
# %scala
mnm_s_par.rdd.getNumPartitions
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res22: Int = 16
# </div>

# %%
# %scala
mnm_s_par.write.format("csv").mode("overwrite").save("/tmp/data/csv/mnm_csv_scala_16par")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls '/tmp/data/csv/mnm_csv_scala_16par'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1651238888000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/_committed_7619795377295868092</td><td>_committed_7619795377295868092</td><td>1432</td><td>1651238887000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/_started_7619795377295868092</td><td>_started_7619795377295868092</td><td>0</td><td>1651238885000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00000-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-43-1-c000.csv</td><td>part-00000-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-43-1-c000.csv</td><td>74038</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00001-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-44-1-c000.csv</td><td>part-00001-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-44-1-c000.csv</td><td>74084</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00002-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-45-1-c000.csv</td><td>part-00002-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-45-1-c000.csv</td><td>74052</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00003-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-46-1-c000.csv</td><td>part-00003-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-46-1-c000.csv</td><td>74040</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00004-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-47-1-c000.csv</td><td>part-00004-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-47-1-c000.csv</td><td>74072</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00005-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-48-1-c000.csv</td><td>part-00005-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-48-1-c000.csv</td><td>74026</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00006-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-49-1-c000.csv</td><td>part-00006-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-49-1-c000.csv</td><td>74010</td><td>1651238885000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00007-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-50-1-c000.csv</td><td>part-00007-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-50-1-c000.csv</td><td>74024</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00008-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-51-1-c000.csv</td><td>part-00008-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-51-1-c000.csv</td><td>74054</td><td>1651238886000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00009-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-52-1-c000.csv</td><td>part-00009-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-52-1-c000.csv</td><td>74068</td><td>1651238887000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00010-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-53-1-c000.csv</td><td>part-00010-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-53-1-c000.csv</td><td>74077</td><td>1651238887000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00011-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-54-1-c000.csv</td><td>part-00011-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-618f6c0d2dd2-54-1-c000.csv</td><td>74072</td><td>1651238887000</td></tr><tr><td>dbfs:/tmp/data/csv/mnm_csv_scala_16par/part-00012-tid-7619795377295868092-1ec2ae96-ffc1-4259-b05d-61 ...

# %% [markdown]
# Se puede ver que en este caso que están los ficheros de los metadatos y los ficheros con las 16 particiones

# %% [markdown]
# ## Capítulo 4

# %% [markdown]
# ### Ejercicio 3
#  Leer los AVRO, Parquet, JSON y CSV escritos en el cap3 (Los dos primeros están en los ficheros *Chapter 4_Pyspark* y *Chapter 4_Scala*)

# %% [markdown]
# #### Python

# %%
#JSON
file = "dbfs:/tmp/data/json/mnm_json/part-00000-tid-6570515074209043752-1c2cd319-6936-47c1-a4ce-f88cb02cb19a-32-1-c000.json"
df_json_p = spark.read.format("json").load(file)
#CSV
df_csv_p = spark.read.csv("dbfs:/tmp/data/csv/mnm_csv/part-00000-tid-5652327037189224389-b98244b7-2bb5-4ec1-98cf-e5477a5b2bdd-33-1-c000.csv", header=True)
#AVRO
df_avro_p = (spark.read.format("avro")
 .load("dbfs:/tmp/data/avro/mnm_avro/part-00000-tid-1804635148172896910-f1b2632a-c937-47de-b56e-601d13ba289a-34-1-c000.avro"))

# %%
print(df_json_p.show(5))
print(df_csv_p.show(5))
print(df_avro_p.show(5))
# Out:
# +------+-----+-----+
# | Color|Count|State|
# +------+-----+-----+
# |   Red|   20|   TX|
# |  Blue|   66|   NV|
# |  Blue|   79|   CO|
# |  Blue|   71|   OR|
# |Yellow|   93|   WA|
# +------+-----+-----+
# only showing top 5 rows
#
# None
# +---+------+---+
# | TX|   Red| 20|
# +---+------+---+
# | NV|  Blue| 66|
# | CO|  Blue| 79|
# | OR|  Blue| 71|
# | WA|Yellow| 93|
# | WY|  Blue| 16|
# +---+------+---+
# only showing top 5 rows
#
# None
# +-----+------+-----+
# |State| Color|Count|
# +-----+------+-----+
# |   TX|   Red|   20|
# |   NV|  Blue|   66|
# |   CO|  Blue|   79|
# |   OR|  Blue|   71|
# |   WA|Yellow|   93|
# +-----+------+-----+
# only showing top 5 rows
#
# None

# %% [markdown]
# #### Scala

# %%
# %scala
//JSON
val df_json_s = spark.read.format("json").load("/tmp/data/json/mnm_json_scala/part-00000-tid-1878550521505857892-d264a3b3-1de3-4c7c-ac6e-98a0a7ae252a-35-1-c000.json")
//CSV
val df_csv_s = spark.read.format("csv")
 .option("header", "true")
 .load("/tmp/data/csv/mnm_csv_scala/part-00000-tid-945854175293185945-b7ee2340-b08f-420e-8f6e-5847d9d8bc89-36-1-c000.csv")
//AVRO
val df_avro_s = spark.read.format("avro")
.load("/tmp/data/avro/mnm_avro_scala/part-00000-tid-3679318734650097166-dc071a35-d528-487a-8c6d-cef9b09b76e1-37-1-c000.avro")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_json_s: org.apache.spark.sql.DataFrame = [Color: string, Count: string ... 1 more field]
# df_csv_s: org.apache.spark.sql.DataFrame = [TX: string, Red: string ... 1 more field]
# df_avro_s: org.apache.spark.sql.DataFrame = [State: string, Color: string ... 1 more field]
# </div>

# %%
# %scala
df_json_s.show(5)
df_csv_s.show(5)
df_avro_s.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----+-----+
#  Color|Count|State|
# +------+-----+-----+
#    Red|   20|   TX|
#   Blue|   66|   NV|
#   Blue|   79|   CO|
#   Blue|   71|   OR|
# Yellow|   93|   WA|
# +------+-----+-----+
# only showing top 5 rows
#
# +---+------+---+
#  TX|   Red| 20|
# +---+------+---+
#  NV|  Blue| 66|
#  CO|  Blue| 79|
#  OR|  Blue| 71|
#  WA|Yellow| 93|
#  WY|  Blue| 16|
# +---+------+---+
# only showing top 5 rows
#
# +-----+------+-----+
# State| Color|Count|
# +-----+------+-----+
#    TX|   Red|   20|
#    NV|  Blue|   66|
#    CO|  Blue|   79|
#    OR|  Blue|   71|
#    WA|Yellow|   93|
# +-----+------+-----+
# only showing top 5 rows
#
# </div>
